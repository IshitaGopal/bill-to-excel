# %%
import pandas as pd

# %%
import os
import sys

src_dir = os.path.join(os.getcwd(), "..", "src")
sys.path.append(src_dir)

# %%
from pdf_parser.extract_revolut import extract_payments

# %%
file = "../data/sample_bills/account-statement_2025-08-01_2025-09-22_en-us_f6e54e.pdf"

# %%
pd.DataFrame(extract_payments(file))
# Out:
#             Date                          Description  Money Out Money In  \
# 0    Aug 1, 2025                     Gorilla Bäckerei      €9.66      NaN
# 1    Aug 1, 2025                      ServiceStore DB      €2.98      NaN
# 2    Aug 2, 2025                         Tweede Kamer      €3.00      NaN
# 3    Aug 2, 2025                                OVpay      €1.43      NaN
# 4    Aug 3, 2025                                OVpay      €9.34      NaN
# ..           ...                                  ...        ...      ...
# 92   Sep 2, 2025                  To Yello Strom GmbH     €40.00      NaN
# 93   Sep 8, 2025          To Telekom Deutschland GmbH     €47.95      NaN
# 94   Sep 8, 2025  To VIP Verkehrsbetrieb Potsdam GmbH     €55.10      NaN
# 95  Sep 16, 2025                    Pocket Withdrawal  €1,000.00      NaN
# 96  Sep 20, 2025                    Pocket Withdrawal    €200.00      NaN
#
#       Balance
# 0   €1,582.86
# 1   €1,579.88
# 2   €1,576.88
# 3   €1,575.45
# ...
